# %%
import json
# Calculate the Euclidean distance
# between two points
from functools import reduce
from textwrap import wrap

import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
from matplotlib.colors import ListedColormap


def distance_2d(x1, y1, x2, y2):
    return ((x1 - x2) ** 2 + (y1 - y2) ** 2) ** (1 / 2)


# Function to calculate K closest points
def kClosest(points, target, K):
    pts = []
    position = []
    dist = []
    n = len(points)
    d = []

    for i in range(n):
        d.append({
            "first": distance_2d(points[i][0], points[i][1], target[0], target[1]),
            "second": i
        })

    d = sorted(d, key=lambda l: l["first"])

    for i in range(K):
        pt = []
        dist.append(d[i]["first"])
        position.append(d[i]["second"])
        pt.append(points[d[i]["second"]][0])
        pt.append(points[d[i]["second"]][1])
        pts.append(pt)

    return dict(zip(position, dist))

# %%
# Function to calculate K closest points
from scipy.spatial import distance


def kClosest_high(points, target, K):
    pts = []
    position = []
    dist = []
    n = len(points)
    d = []

    for i in range(n):
        d.append({
            "first": distance.cosine(points[i], target),
            "second": i
        })

    d = sorted(d, key=lambda l: l["first"])

    pt = []
    for i in range(K):
        dist.append(d[i]["first"])
        position.append(d[i]["second"])
        # pt.append(points[d[i]["second"]])
    return dict(zip(position, dist))

# %%
def load_points(model, article, k):
    f = open(f'../embeddings/high_dimension/{model}_high_dim.json')
    data = json.load(f)
    target = data[article]
    articles_title = list(data.keys())
    corpus_embedding = list(data.values())
    closest_points = kClosest_high(corpus_embedding, target, k)
    near_values = {}
    for k in closest_points.keys():
        # if(closest_points[k] != 0.0):
        near_values[articles_title[k]] = closest_points[k]
    return near_values

# %%
def draw_plot(target_title, K):
    # models = ['all_mpnet_base_v2', 'allenai_specter', 'biowordvec',
    #           'generic_fasttext']
    # model_names = ['all-mpnet-base-v2', 'allenai-specter', 'BioWordVec',
    #           'Generic fastText']
    # models = ['all_mpnet_base_v2', 'allenai_specter', 'pubmedbert', 'biowordvec', 'generic_fasttext', 'tfidf', 'bow']
    # model_names = ['all-mpnet-base-v2', 'allenai-specter', 'PubMedBERT', 'Avg. BioWordVec', 'Avg. Generic fastText',
    #                'TFIDF', 'BOW']
    models = ['biowordvec', 'generic_fasttext']
    model_names = ['Avg. BioWordVec', 'Avg. Generic fastText']
    # models = ['allenai_specter','all_mpnet_base_v2']
    # model_names = ['allenai_specter', 'pubmedbert']
    # models = ['allenai_specter', 'pubmedbert']

    all_points = {model: load_points(model, target_title, k=236) for model in models}
    points = {model: load_points(model, target_title, k=K) for model in models}

    # print(len(points))
    allkey = reduce(set.union, map(set, map(dict.keys, points.values())))
    if target_title in allkey:
        allkey.remove(target_title)

    d = np.zeros((len(allkey), len(models)))
    all_dist = []
    index_a = []
    for key in allkey:
        item = [points[m][key] if key in points[m] else all_points[m][key] for m in models]
        a = [list(points[m].keys()).index(key) if key in points[m] else list(all_points[m].keys()).index(key) for m in
             models]
        index_a.append(a)
        all_dist.append(item)

    A = np.array(all_dist)
    B = np.array(index_a)
    avg = np.average(A, axis=0)

    labels = ['\n'.join(wrap(l, 40)) for l in allkey]
    fig, ax = plt.subplots(figsize=(6, 8))
    # my_colors = ['#08c45b', '#eded72','#926dd1']
    my_colors = ['#08c45b']
    my_cmap = ListedColormap(my_colors)
    my_cmap.set_over('#eb4f34')
    ax = sns.heatmap(B, xticklabels=model_names, yticklabels=labels, annot=A, cbar_kws={'label': 'Publication Ranks',
                                                                                        'extend': 'max',
                                                                                        'ticks': [1, 4]},
                     cmap=my_cmap, vmin=1, vmax=4, cbar=True, ax=ax,
                     annot_kws={'fontsize': 12, 'color': 'black', 'alpha': 1}, linewidths=0.08, linecolor='lightgray')
    # ax = sns.heatmap(B, mask=B < 2, cmap='Blues', annot=A,xticklabels=models, yticklabels=allkey, vmin=0, vmax=1, cbar=False, ax=ax)
    # colorbar = ax.collections[0].colorbar
    # colorbar.set_ticks([1,5])
    # colorbar.set_ticklabels(['1', '4'])
    plt.title(label=f'Distance from \"{target_title}\"', fontsize=10, fontstyle='oblique')
    plt.show()
    return B

# %%
target_title1 = "Visual Analytics in Digital Pathology: Challenges and Opportunities"
B = draw_plot(target_title1, 4)
B = np.array(B)
B
# Out:
# Visual Analytics in Digital Pathology: Challenges and Opportunities : 0
# Visual Analytics in Histopathology Diagnostics: a Protocol-Based Approach : 0.04152323098437194
# PATHONE: From one Thousand Patients to one Cell : 0.09843051130024771
# Discovering Medical Knowledge Using Visual Analytics : 0.1350872502478403
# Visual Analytics for the Exploration and Assessment of Segmentation Errors : 0.141387575349048
# RegistrationShop: An Interactive 3D Medical Volume Registration System : 0.15358504830637132
# A Visual Analytics Approach for Patient Stratification and Biomarker Discovery : 0.15454987294478284
# Survey of Labeling Techniques in Medical Visualizations : 0.15998004769794827
# VisualFlatter - Visual Analysis of Distortions in the Projection of Biomedical Structures : 0.17105139890330334
# A Critical Analysis of the Evaluation Practice in Medical Visualization : 0.1720126375282538
# Extracting and Visualizing Uncertainties in Segmentations from 3D Medical Data : 0.17725845872073298
# Real-Time Guidance and Anatomical Information by Image Projection onto Patients : 0.1792439655017467
# A Web-based Application for the Visual Exploration of Colon Morphology Data : 0.17989021876504907
# Interactive Labeling of Toponome Data : 0.18083964555969712
# Sline: Seamless Line Illustration for Interactive Biomedical Visualization : 0.18451001511598097
# InShaDe: Invariant Shape Descriptors for Visual Analysis of Histology 2D Cellular and Nuclear Shapes : 0.1864082542840083
# Guided Visualization of Ultrasound Image Sequences : 0.18745567492631365
# Anatomical Volume Visualization with Weighted Distance Fields : 0.1877493968315187
# A Statistical Method for Surface Detection : 0.18909822114704034
# Visual Analysis of Medical Image Segmentation Feature Space for Interactive Supervised Classification : 0.19125687516873568
# Vologram: An Educational Holographic Sculpture for Volumetric Medical Data Physicalization : 0.19469806393465594
# QuantiScale: A Study in Redesigning Interactions for Multi-Touch : 0.19961557207922598
# FluoroSim: A Visual Problem-Solving Environment for Fluorescence Microscopy : 0.1999021792147303
# From Imprecise User Input to Precise Vessel Segmentations : 0.2000233743561498
# Concentric Circle Glyphs for Enhanced Depth-Judgment in Vascular Models : 0.2007997946144785
# Parameterization and Feature Extraction for the Visualization of Tree-like Structures : 0.20116475464861672
# Feature Exploration using Local Frequency Distributions in Computed Tomography Data : 0.20327931621411843
# Information-based Transfer Functions for Multimodal Visualization : 0.20481172570673511
# HIFUpm: a Visual Environment to Plan and Monitor High Intensity Focused Ultrasound Treatments : 0.20622814993516958
# The Role of Depth Perception in XR from a Neuroscience Perspective: A Primer and Survey : 0.2073625256865167
# A Survey on Visualizing Magnetic Resonance Spectroscopy Data : 0.2088465023419558
# Towards Clinical Deployment of Automated Anatomical Regions-Of-Interest : 0.2094204428543961
# How to Evaluate Medical Visualizations on the Example of 3D Aneurysm Surfaces : 0.21013387619297785
# Volume Visualization Using Principal Component Analysis : 0.21016603519162647
# GLANCE: Visual Analytics for Monitoring Glaucoma Progression : 0.2102956007520823
# Illustrated Ultrasound for Multimodal Data Interpretation of Liver Examinations : 0.21105236189141796
# Visual Analysis of Multivariate Intensive Care Surveillance Data : 0.2134361071933082
# Multiple Scale Visualization of Electronic Health Records to Support Finding Medical Narratives : 0.2139410356893644
# Importance-Driven Structure Categorization for 3D Surgery Planning : 0.21593685154757625
# Visibility-Driven Processing of Streaming Volume Data : 0.21598525496145193
# SpectraMosaic: An Exploratory Tool for the Interactive Visual Analysis of Magnetic Resonance Spectroscopy Data : 0.21600449831092716
# Constrained Labeling of 2D Slice Data for Reading Images in Radiology : 0.21738834773941185
# ICG based Augmented-Reality-System for Sentinel Lymph Node Biopsy : 0.21763008233831427
# Visualization-Guided Evaluation of Simulated Minimally Invasive Cancer Treatment : 0.21778378033197687
# Pelvis Runner: Visualizing Pelvic Organ Variability in a Cohort of Radiotherapy Patients : 0.21875434925655624
# The iCoCooN: Integration of Cobweb Charts with Parallel Coordinates for Visual Analysis of DCE-MRI Modeling Variations : 0.2213252300377655
# Visualization and Exploration of 3D Toponome Data : 0.22153097963211776
# Visual Navigation Support for Liver Applicator Placement using Interactive Map Displays : 0.223281748373101
# Automatic Generation of Web-Based User Studies to Evaluate Depth Perception in Vascular Surface Visualizations : 0.22361105940118953
# Surface Curvature Line Clustering for Polyp Detection in CT Colonography : 0.22498670520901165
# Automatic Hepatocyte Quantification from Histological Images: Comparing Pre-smoothing filters : 0.22582460337735966
# HIFUtk: Visual Analytics for High Intensity Focused Ultrasound Simulation : 0.22603786575018636
# DockVis: Visual Analysis of Molecular Docking Data : 0.2271496079069082
# Improving Perception of Molecular Surface Visualizations by Incorporating Translucency Effects : 0.22928962876334635
# GPU Accelerated Normalized Mutual Information and B-Spline Transformation : 0.23027943062447398
# Interactive Position-dependent Customization of Transfer Function Classification Parameters in Volume Rendering : 0.23037093185825397
# Combining Pseudo Chroma Depth Enhancement and Parameter Mapping for Vascular Surface Models : 0.2305066454837431
# Visually Guided Mesh Smoothing for Medical Applications : 0.23071964755302055
# Graxels: Information Rich Primitives for the Visualization of Time-Dependent Spatial Data : 0.230772533892865
# A General Approach to Model Biomedical Data from 3D Unorganised Point Clouds with Medial Scaffolds : 0.23140200388612464
# An Exploration of Practice and Preferences for the Visual Communication of Biomedical Processes : 0.23306893910008475
# A Guided Spatial Transformer Network for Histology Cell Differentiation : 0.2342190137201845
# Progressive and Efficient Multi-Resolution Representations for Brain Tractograms : 0.23534396457345574
# Comparative Visualization for Diffusion Tensor Imaging Group Study at Multiple Levels of Detail : 0.2353703290379433
# Mammogram Classification and Abnormality Detection from Nonlocal Labels using Deep Multiple Instance Neural Network : 0.23598640690160633
# preha: Establishing Precision Rehabilitation with Visual Analytics : 0.23655919799334413
# Efficient Globally Optimal Matching of Anatomical Trees of the Liver : 0.23784418407110808
# Visual Analytics of Missing Data in Epidemiological Cohort Studies : 0.23852909893113172
# Medical Animations: A Survey and a Research Agenda : 0.23886818697137868
# InkVis: A High-Particle-Count Approach for Visualization of Phase-Contrast Magnetic Resonance Imaging Data : 0.2392350229498028
# A Prototype Holographic Augmented Reality Interface for Image-Guided Prostate Cancer Interventions : 0.24007097639447528
# Focus + Context Rendering of Structured Biomedical Data : 0.24011849965179843
# Visual Analysis and Comparison of Multiple Sequence Alignments : 0.24094610980098474
# Uncertainty Estimation and Visualization for Multi-modal Image Segmentation : 0.2415978563076513
# Chameleon - Dynamic Color Mapping for Multi-Scale Structural Biology Models : 0.24164273916557433
# Sketch-based Image-independent Editing of 3D Tumor Segmentations using Variational Interpolation : 0.24208688878508033
# Molecular Sombreros: Abstract Visualization of Binding Sites within Proteins : 0.2420883076059116
# Shading Style Assessment for Vessel Wall and Lumen Visualization : 0.24275859671831213
# Maximizing AUC with Deep Learning for Classification of Imbalanced Mammogram Datasets : 0.24377909613975213
# Unfolding and Interactive Exploration of Protein Tunnels and their Dynamics : 0.24443137932105807
# A Framework for Visual Comparison of 4D PC-MRI Aortic Blood Flow Data : 0.2444462614869607
# Visual Analysis of Bipartite Biological Networks : 0.2447670689949163
# Imaging the Vascular Network of the Human Spleen from Immunostained Serial Sections : 0.24741359778362593
# Tractography in Context: Multimodal Visualization of Probabilistic Tractograms in Anatomical Context : 0.24762835292974217
# Semantic Screen-Space Occlusion for Multiscale Molecular Visualization : 0.2481297496280117
# Projection Mapping for In-Situ Surgery Planning by the Example of DIEP Flap Breast Reconstruction : 0.24816071479936852
# Fast and Smooth Interactive Segmentation of Medical Images Using Variational Interpolation : 0.24881810965538986
# Model-based Solid Texture Synthesis for Anatomic Volume Illustration : 0.24938191483239236
# Glyph-Based Visualization of Myocardial Perfusion Data and Enhancement with Contractility and Viability Information : 0.24940765348286686
# Illustrative Multi-volume Rendering for PET/CT Scans : 0.24946458744325506
# Dynamic Visualisation of Orbital Fat Deformation using Anatomy-Guided Interaction : 0.2503949803298986
# FoldSynth: Interactive 2D/3D Visualisation Platform for Molecular Strands : 0.2505109029992839
# Real-Time Visualization of 3D Amyloid-Beta Fibrils from 2D Cryo-EM Density Maps : 0.25053780240872914
# Visual Assessment of Vascular Torsion using Ellipse Fitting : 0.25136422276820325
# Image Registration Methods for Patient-Specific Virtual Physiological Human Models : 0.2533905152367233
# Distance Field Visualization and 2D Abstraction of Vessel Tree Structures with on-the-fly Parameterization : 0.2534216775188123
# Real-Time Dense Nucleus Selection from Confocal Data : 0.25355978095775866
# An Integrated Platform for Dynamic Cardiac Simulation and Image Processing: Application to Personalised Tetralogy of Fallot Simulation : 0.25496536685740534
# Instant Visualization of Secondary Structures of Molecular Models : 0.2552924590142822
# Interactive Visual Similarity Analysis of Measured and Simulated Multi-field Tubular Flow Ensembles : 0.2553034090455718
# Exploration of 3D Medical Image Data for Interventional Radiology using Myoelectric Gesture Control : 0.2557214837381363
# The Vitruvian Baby: Interactive Reformation of Fetal Ultrasound Data to a T-Position : 0.2562219868709581
# Automatic Segmentation of the Pelvic Bones from CT Data Based on a Statistical Shape Model : 0.2564008337683129
# A Visual Environment for Hypothesis Formation and Reasoning in Studies with fMRI and Multivariate Clinical Data : 0.25642372642889333
# 2.5D Geometric Mapping of Aortic Blood Flow Data for Cohort Visualization : 0.2574357914824825
# Evaluation of Transfer Function Methods in Direct Volume Rendering of the Blood Vessel Lumen : 0.25756049159847993
# A New Vessel Enhancement Transform on Retinal Blood Vessels Segmentation : 0.2589513179770532
# Computation and Visualization of Asynchronous Behavior of the Heart : 0.2593526737073989
# A Survey of Cardiac 4D PC-MRI Data Processing : 0.25940337438214
# Automated Slice-Based Artery Identification in Various Field-of-View CTA Scans : 0.26025252895192286
# Atomistic Visualization of Mesoscopic Whole-Cell Simulations : 0.2605745790595294
# Semi-Immersive 3D Sketching of Vascular Structures for Medical Education : 0.2622250297842007
# Personalized X-ray Reconstruction of the Proximal Femur via a New Control Point-based 2D-3D Registration and Residual Complexity Minimization : 0.2627749138563762
# Combining B-Mode and Color Flow Vessel Segmentation for Registration of Hepatic CT and Ultrasound Volumes : 0.26367956599663656
# Layer-Aware iOCT Volume Rendering for Retinal Surgery : 0.2641395195457583
# cellVIEW: a Tool for Illustrative and Multi-Scale Rendering of Large Biomolecular Datasets : 0.2641608447682051
# Interactive Formation of Statistical Hypotheses in Diffusion Tensor Imaging : 0.2658491318441385
# A Feasibility Study on Automated Protein Aggregate Characterization Utilizing a Hybrid Classification Model : 0.26612841797795717
# A Web-Based Tool for Cardiac Dyssynchrony Assessment on Ultrasound Data : 0.2678145497868122
# Introducing CNN-Based Mouse Grim Scale Analysis for Fully Automated Image-Based Assessment of Distress in Laboratory Mice : 0.2680147611890923
# Automatic Animations to Analyze Blood Flow Data : 0.2680571756848531
# Spatio-temporal Visualization of Regional Myocardial Velocities : 0.26974768911496627
# Interactive Multimodal Imaging Visualization for Multiple Sclerosis Lesion Analysis : 0.2711690176075502
# Illustrative Transitions in Molecular Visualization via Forward and Inverse Abstraction Transform : 0.27141096348273186
# Staircase-Aware Smoothing of Medical Surface Meshes : 0.2721112473837758
# Colonic Content Assessment from MRI Imaging Using a Semi-automatic Approach : 0.27219973883599746
# PerSleep: A Visual Analytics Approach for Performance Assessment of Sleep Staging Models : 0.27244567089441774
# The BundleExplorer: A Focus and Context Rendering Framework for Complex Fiber Distributions : 0.272467653266822
# Automatic Real-time Annotation of Important Landmarks in Ultrasound-Guided Femoral Nerve Blocks : 0.2725104572142968
# Uncertainty-aware Brain Lesion Visualization : 0.27312834203749414
# VRIDAA: Virtual Reality Platform for Training and Planning Implantations of Occluder Devices in Left Atrial Appendages : 0.2733808628448602
# Uncertainty-Guided Semi-Automated Editing of CNN-based Retinal Layer Segmentations in Optical Coherence Tomography : 0.27361492966786827
# A Two-Level Cascade Classification Algorithm for Real-Time Bifurcation Detection in CTA Images of Blood Vessels : 0.2740196868004159
# The Virtual Reality Flow Lens for Blood Flow Exploration : 0.27572426505406866
# Interactive Exploded Views for Molecular Structures : 0.2759247896289654
# Membrane Mapping: Combining Mesoscopic and Molecular Cell Visualization : 0.27619814992332414
# Coherence Maps for Blood Flow Exploration : 0.2790871484187609
# Interactive Residual Stress Modeling for Soft Tissue Simulation : 0.2791309176511747
# Automatic Cutting and Flattening of Carotid Artery Geometries : 0.27978154631247054
# A Framework for Fast Initial Exploration of PC-MRI Cardiac Flow : 0.2800504069634684
# Bone Fracture and Lesion Assessment using Shape-Adaptive Unfolding : 0.2800654128446721
# Visual Analysis of Regional Anomalies in Myocardial Motion : 0.28052818602229534
# Deriving Anatomical Context from 4D Ultrasound : 0.28269868971565193
# Robust Classification and Analysis of Anatomical Surfaces Using 3D Skeletons : 0.28295735479443274
# Semi-Automatic Vessel Boundary Detection in Cardiac 4D PC-MRI Data Using FTLE fields : 0.28432725916979995
# Polar Space Based Shape Averaging for Star-shaped Biological Objects : 0.28672360096290483
# SWiFT Seeing the Wood From the Trees: helping people make sense of their health data : 0.28725536886890524
# On the Value of Multi-Volume Visualization for Preoperative Planning of Cerebral AVM Surgery : 0.2873757572333493
# BrainCove: A Tool for Voxel-wise fMRI Brain Connectivity Visualization : 0.28856200398075704
# A Haptics-enabled Simulator for Transperineal Ultrasound-Guided Biopsy : 0.28965792449335936
# MedUse: A Visual Analysis Tool for Medication Use Data in the ABCD Study : 0.289797546619356
# Estimation of the Midsagittal Plane for Sideness Determination of Malignant Structures of Head and Neck : 0.29017663924118897
# Ultrasound Decompression for Large Field-of-View Reconstructions : 0.2902107929559722
# Aneulysis - A System for Aneurysm Data Analysis : 0.2913507251566849
# Generation of a Mean Motion Model of the Lung Using 4D-CT Image Data : 0.29152982228640556
# Analyzing Protein Similarity by Clustering Molecular Surface Maps : 0.2917857605099953
# Inlier Detection in Thermal Sensitive Images : 0.29200191580928725
# Histology-Based Evaluation of Optical Coherence Tomographic Characteristics of the Cerebral Artery Wall via Virtual Inflating : 0.293445833664582
# Impact of Physical Noise Modeling on Image Segmentation in Echocardiography : 0.29372646519609846
# Visualisation of PET data in the Fly Algorithm : 0.2938839643462673
# Visual Assessment of Growth Prediction in Brain Structures after Pediatric Radiotherapy : 0.2967997858121758
# Interactive CPU-based Ray Tracing of Solvent Excluded Surfaces : 0.29698511968642405
# Reconstruction of Blood Vessels from Neck CT Datasets using Stable 3D Mass-Spring Models : 0.2985667804756549
# MRI Hip Joint Segmentation: A Locally Bhattacharyya Weighted Hybrid 3D Level Set Approach : 0.29866556175981185
# Hybrid Visualization of Protein-Lipid and Protein-Protein Interaction : 0.29888683181257536
# Simulation-based Ultrasound Training Supported by Annotations, Haptics and Linked Multimodal Views : 0.2989471496776904
# Exploration of Interventricular Septum Motion in Multi-Cycle Cardiac MRI : 0.29926672612708505
# Robust Cardiac Function Assessment in 4D PC-MRI Data : 0.2999901824434468
# UI-Net: Interactive Artificial Neural Networks for Iterative Image Segmentation Based on a User Model : 0.30038300358829373
# Iterative Exploration of Big Brain Network Data : 0.3025094012103883
# Misalignment Correction in Open Cone-Beam CT : 0.3025616065332677
# Aortic Dissection Maps: Comprehensive Visualization of Aortic Dissections for Risk Assessment : 0.303084838408739
# Strategies for Generating Multi-Time Frame Localization of Cardiac MRI : 0.3046870646164971
# Lowest-Variance Streamlines for Filtering of 3D Ultrasound : 0.3047180113293533
# Deriving and Visualizing Uncertainty in Kinetic PET Modeling : 0.3047650077118358
# CT Late Enhancement Segmentation for the Combined Analysis of Coronary Arteries and Myocardial Viability : 0.30492373278840224
# Automatic Thrombus Detection in Non-enhanced Computed Tomography Images in Patients With Acute Ischemic Stroke : 0.30494264598202014
# Watergate: Visual Exploration of Water Trajectories in Protein Dynamics : 0.3050990516731419
# CoWRadar: Visual Quantification of the Circle of Willis in Stroke Patients : 0.305754962250426
# A Multilinear Model for Bidirectional Craniofacial Reconstruction : 0.3068970795882462
# Global and Local Mesh Morphing for Complex Biological Objects from µCT Data : 0.3075487294104601
# Evaluation of Hippocampal Segmentation Methods for Healthy and Pathological Subjects : 0.3077979947955818
# VirtualDSA++: Automated Segmentation, Vessel Labeling, Occlusion Detection and Graph Search on CT-Angiography Data : 0.30786073765136257
# An Endoscope Interface for Immersive Virtual Reality : 0.30823150662184606
# Interactive Visualization of Muscle Activity During Limb Movements: Towards Enhanced Anatomy Learning : 0.3083723779036682
# Learning Hand Anatomy with Sense of Embodiment : 0.30967618208969416
# Adapted Surface Visualization of Cerebral Aneurysms with Embedded Blood Flow Information : 0.3118572878507231
# Motion-moderated Transfer Function for Volume Rendering 4D CMR Data : 0.3141437079786411
# Haptics-based Modelling of Pigmented Skin Lesions : 0.3156841189932744
# Visual Exploratory Analysis for Multiple T-Maze Studies : 0.31713589344465576
# Recent Advances in MRI and Ultrasound Perfusion Imaging : 0.3175688931938784
# Application of Image Processing Functions for Brain Tumor Enhancement in Intraoperative Ultrasound Image Data : 0.31815017839098325
# Interactive Classification of Multi-Shell Diffusion MRI With Features From a Dual-Branch CNN Autoencoder : 0.3191217571501975
# High-Quality Multimodal Volume Visualization of Intracerebral Pathological Tissue : 0.31962443958552766
# Illustrative PET/CT Visualisation of SIRT-Treated Lung Metastases : 0.31986436323166556
# Visualizing White Matter Fiber Tracts with Optimally Fitted Curved Dissection Surfaces : 0.3198672048557246
# Monte-Carlo Ray-Tracing for Realistic Interactive Ultrasound Simulation : 0.32119318044011747
# Fiber Stipples for Crossing Tracts in Probabilistic Tractography : 0.32152937084987854
# Computational Steering for Patient-Specific Implant Planning in Orthopedics : 0.3221673226195285
# Multiparametric Magnetic Resonance Image Synthesis using Generative Adversarial Networks : 0.3225602750763593
# Visualizing Movements of Protein Tunnels in Molecular Dynamics Simulations : 0.3232801161565093
# Geometrical-Acoustics-based Ultrasound Image Simulation : 0.32605758108242033
# Schematic Electrode Map for Navigation in Neuro Data Sets : 0.32629217183042813
# Protein Tunnel Reprojection for Physico-Chemical Property Analysis : 0.32708812151994093
# Visual Analysis of Integrated Resting State Functional Brain Connectivity and Anatomy : 0.3284869377020795
# Evolutionary Pathlines for Blood Flow Exploration in Cerebral Aneurysms : 0.32929402744858316
# AR-Assisted Craniotomy Planning for Tumour Resection : 0.33278998048305264
# Ontology-Based Visualization of Hierarchical Neuroanatomical Structures : 0.3331652539794504
# Uncertainty-aware Ensemble of Classifiers for Segmenting Brain MRI Data : 0.3334246937673786
# Design Considerations for Immersive Analytics of Bird Movements Obtained by Miniaturised GPS Sensors : 0.33418159911619405
# Estimation of Muscle Activity in One-Leg Stance from 3D Surface Deformation : 0.33506153452931475
# Simulated Motion Artefact in Computed Tomography : 0.3350760401044186
# Synaptic Connectivity in Anatomically Realistic Neural Networks: Modeling and Visual Analysis : 0.33796386998219674
# Robustness Evaluation of CFD Simulations to Mesh Deformation : 0.34100449139114275
# Student and Teacher Meet in a Shared Virtual Reality: A one-on-one Tutoring System for Anatomy Education : 0.3458789932600357
# Feasibility Study For Automatic Bird Tracking and Visualization from Time-Dependent Marine Radar Imagery : 0.34703478807557864
# A Comparative User Study of a 2D and an Autostereoscopic 3D Display for a Tympanoplastic Surgery : 0.3486905914153541
# CT-Based Navigation Guidance for Liver Tumor Ablation : 0.3492801952235093
# Visual Analysis of Evolution of EEG Coherence Networks employing Temporal Multidimensional Scaling : 0.35090523647112837
# Accelerated Diffusion Operators for Enhancing DW-MRI : 0.360188193179222
# Graph Averaging as a Means to Compare Multichannel EEG Coherence Networks : 0.3610816527423307
# Parametric-based Reconstruction Of 3D Mesh Models; Towards the Generation of a Parametric Human Foot Biomodel : 0.36437365020381995
# Computation of More Channels in Protein Molecules : 0.36506066444094176
# Semantic Segmentation of Brain Tumors in MRI Data Without any Labels : 0.36519565147183786
# VR Acrophobia Treatment - Development of Customizable Acrophobia Inducing Scenarios : 0.36618008541645986
# Reducing Model Uncertainty in Crossing Fiber Tractography : 0.3673415234624897
# Annotated Dendrograms for Neurons From the Larval Fruit Fly Brain : 0.3677233239302876
# Visual and Quantitative Analysis of Higher Order Arborization Overlaps for Neural Circuit Research : 0.37300364354811666
# Temporal Interpolation of 4D PC-MRI Blood-flow Measurements Using Bidirectional Physics-based Fluid Simulation : 0.3770237947183862
# A Haptic Rendering Algorithm for Molecular Interaction : 0.3787167568427855
# Visualizing and Exploring Dynamic Multichannel EEG Coherence Networks : 0.38063195356468116
# Multi-fiber Estimation and Tractography for Diffusion MRI using mixture of Non-central Wishart Distributions : 0.3815797787979316
# Using Position-Based Dynamics for Simulating the Mitral Valve in a Decision Support System : 0.38873267995394856
# Fully Automatic Skull-Stripping in 3D Time-of-Flight MRA Image Sequences : 0.39648727504205816
# Interactive Real Time Simulation of Cardiac Radio-Frequency Ablation : 0.39766978845563494
# Challenges and Technologies for Low Cost Wheelchair Simulation : 0.4146672888800166
# Visual Analytics in Digital Pathology: Challenges and Opportunities : 0
# Visual Analytics in Histopathology Diagnostics: a Protocol-Based Approach : 0.043578611853863025
# GLANCE: Visual Analytics for Monitoring Glaucoma Progression : 0.05849451299711139
# Discovering Medical Knowledge Using Visual Analytics : 0.06178798678688868
# PerSleep: A Visual Analytics Approach for Performance Assessment of Sleep Staging Models : 0.06208609389640496
# Watergate: Visual Exploration of Water Trajectories in Protein Dynamics : 0.06440287724708471
# Pelvis Runner: Visualizing Pelvic Organ Variability in a Cohort of Radiotherapy Patients : 0.06600563325653597
# Membrane Mapping: Combining Mesoscopic and Molecular Cell Visualization : 0.06607974716249743
# Sline: Seamless Line Illustration for Interactive Biomedical Visualization : 0.06639754491970473
# Semi-Immersive 3D Sketching of Vascular Structures for Medical Education : 0.06860915371269072
# Automatic Generation of Web-Based User Studies to Evaluate Depth Perception in Vascular Surface Visualizations : 0.06978531795732734
# A Visual Environment for Hypothesis Formation and Reasoning in Studies with fMRI and Multivariate Clinical Data : 0.06981903111431298
# VRIDAA: Virtual Reality Platform for Training and Planning Implantations of Occluder Devices in Left Atrial Appendages : 0.07129866203906321
# Visual Navigation Support for Liver Applicator Placement using Interactive Map Displays : 0.07225991449173019
# Combining Pseudo Chroma Depth Enhancement and Parameter Mapping for Vascular Surface Models : 0.07424966760272111
# SpectraMosaic: An Exploratory Tool for the Interactive Visual Analysis of Magnetic Resonance Spectroscopy Data : 0.0744041849976641
# Aneulysis - A System for Aneurysm Data Analysis : 0.07461405077808902
# Multiple Scale Visualization of Electronic Health Records to Support Finding Medical Narratives : 0.07485179567566291
# Visualization-Guided Evaluation of Simulated Minimally Invasive Cancer Treatment : 0.07508988360674174
# Protein Tunnel Reprojection for Physico-Chemical Property Analysis : 0.07526323844826344
# Vologram: An Educational Holographic Sculpture for Volumetric Medical Data Physicalization : 0.0764520870472486
# Schematic Electrode Map for Navigation in Neuro Data Sets : 0.07654807487164739
# Evolutionary Pathlines for Blood Flow Exploration in Cerebral Aneurysms : 0.07679634175378658
# preha: Establishing Precision Rehabilitation with Visual Analytics : 0.07681578358068741
# QuantiScale: A Study in Redesigning Interactions for Multi-Touch : 0.07700762680150741
# The Role of Depth Perception in XR from a Neuroscience Perspective: A Primer and Survey : 0.07730971905717876
# Projection Mapping for In-Situ Surgery Planning by the Example of DIEP Flap Breast Reconstruction : 0.07783717775558185
# Glyph-Based Visualization of Myocardial Perfusion Data and Enhancement with Contractility and Viability Information : 0.07811960566437526
# Mammogram Classification and Abnormality Detection from Nonlocal Labels using Deep Multiple Instance Neural Network : 0.07848586169771177
# Chameleon - Dynamic Color Mapping for Multi-Scale Structural Biology Models : 0.07882944420272064
# The Virtual Reality Flow Lens for Blood Flow Exploration : 0.078888262660185
# Graxels: Information Rich Primitives for the Visualization of Time-Dependent Spatial Data : 0.0794819875464331
# HIFUpm: a Visual Environment to Plan and Monitor High Intensity Focused Ultrasound Treatments : 0.07968551198191187
# An Exploration of Practice and Preferences for the Visual Communication of Biomedical Processes : 0.08121811741502794
# A Critical Analysis of the Evaluation Practice in Medical Visualization : 0.08135404660543477
# Aortic Dissection Maps: Comprehensive Visualization of Aortic Dissections for Risk Assessment : 0.08157847598862644
# Student and Teacher Meet in a Shared Virtual Reality: A one-on-one Tutoring System for Anatomy Education : 0.08179916905201301
# Visual Analytics for the Exploration and Assessment of Segmentation Errors : 0.08195767962375022
# InkVis: A High-Particle-Count Approach for Visualization of Phase-Contrast Magnetic Resonance Imaging Data : 0.08206586384376768
# Exploration of 3D Medical Image Data for Interventional Radiology using Myoelectric Gesture Control : 0.08210354860811087
# Synaptic Connectivity in Anatomically Realistic Neural Networks: Modeling and Visual Analysis : 0.08230615929497753
# FluoroSim: A Visual Problem-Solving Environment for Fluorescence Microscopy : 0.08233802779013644
# Computation and Visualization of Asynchronous Behavior of the Heart : 0.082347149708625
# The Vitruvian Baby: Interactive Reformation of Fetal Ultrasound Data to a T-Position : 0.08235716862112796
# BrainCove: A Tool for Voxel-wise fMRI Brain Connectivity Visualization : 0.08237956367513055
# Visual and Quantitative Analysis of Higher Order Arborization Overlaps for Neural Circuit Research : 0.08240927375400431
# Real-Time Visualization of 3D Amyloid-Beta Fibrils from 2D Cryo-EM Density Maps : 0.08269319404412323
# Illustrative Multi-volume Rendering for PET/CT Scans : 0.08275845869164844
# Visualization and Exploration of 3D Toponome Data : 0.0828159107418156
# A Visual Analytics Approach for Patient Stratification and Biomarker Discovery : 0.08301018343701394
# Real-Time Dense Nucleus Selection from Confocal Data : 0.08310836215232409
# PATHONE: From one Thousand Patients to one Cell : 0.08329879756319192
# Model-based Solid Texture Synthesis for Anatomic Volume Illustration : 0.08340792899337268
# Interactive Formation of Statistical Hypotheses in Diffusion Tensor Imaging : 0.0835475431436471
# RegistrationShop: An Interactive 3D Medical Volume Registration System : 0.08374383107524552
# Layer-Aware iOCT Volume Rendering for Retinal Surgery : 0.08380691654473615
# Atomistic Visualization of Mesoscopic Whole-Cell Simulations : 0.08383682488250122
# Interactive Residual Stress Modeling for Soft Tissue Simulation : 0.08384102714041741
# From Imprecise User Input to Precise Vessel Segmentations : 0.08427430448988793
# CT-Based Navigation Guidance for Liver Tumor Ablation : 0.08441245640358352
# Extracting and Visualizing Uncertainties in Segmentations from 3D Medical Data : 0.08445380042964579
# Iterative Exploration of Big Brain Network Data : 0.08446362945311237
# Application of Image Processing Functions for Brain Tumor Enhancement in Intraoperative Ultrasound Image Data : 0.08458282134588091
# A Prototype Holographic Augmented Reality Interface for Image-Guided Prostate Cancer Interventions : 0.08520356979772092
# Simulation-based Ultrasound Training Supported by Annotations, Haptics and Linked Multimodal Views : 0.08558199403947697
# ICG based Augmented-Reality-System for Sentinel Lymph Node Biopsy : 0.0857626465081861
# Spatio-temporal Visualization of Regional Myocardial Velocities : 0.08618046113124089
# Design Considerations for Immersive Analytics of Bird Movements Obtained by Miniaturised GPS Sensors : 0.08635800404113492
# VR Acrophobia Treatment - Development of Customizable Acrophobia Inducing Scenarios : 0.08647514228743558
# Sketch-based Image-independent Editing of 3D Tumor Segmentations using Variational Interpolation : 0.08666938910986377
# Deriving and Visualizing Uncertainty in Kinetic PET Modeling : 0.08687032979082498
# InShaDe: Invariant Shape Descriptors for Visual Analysis of Histology 2D Cellular and Nuclear Shapes : 0.08689274153219462
# Interactive CPU-based Ray Tracing of Solvent Excluded Surfaces : 0.08690393709682354
# An Integrated Platform for Dynamic Cardiac Simulation and Image Processing: Application to Personalised Tetralogy of Fallot Simulation : 0.087209346309858
# Tractography in Context: Multimodal Visualization of Probabilistic Tractograms in Anatomical Context : 0.08723227014362589
# Uncertainty-aware Brain Lesion Visualization : 0.08735022460400088
# Hybrid Visualization of Protein-Lipid and Protein-Protein Interaction : 0.08748324542401598
# The iCoCooN: Integration of Cobweb Charts with Parallel Coordinates for Visual Analysis of DCE-MRI Modeling Variations : 0.08752877701704243
# Adapted Surface Visualization of Cerebral Aneurysms with Embedded Blood Flow Information : 0.08763539828227984
# Visual Analysis of Multivariate Intensive Care Surveillance Data : 0.08801409928970427
# Interactive Exploded Views for Molecular Structures : 0.08802069428582282
# Uncertainty Estimation and Visualization for Multi-modal Image Segmentation : 0.08810918318952432
# VisualFlatter - Visual Analysis of Distortions in the Projection of Biomedical Structures : 0.08832691723618658
# Comparative Visualization for Diffusion Tensor Imaging Group Study at Multiple Levels of Detail : 0.08837031183854849
# Robust Cardiac Function Assessment in 4D PC-MRI Data : 0.08840750970269984
# Towards Clinical Deployment of Automated Anatomical Regions-Of-Interest : 0.08845050576508418
# Fiber Stipples for Crossing Tracts in Probabilistic Tractography : 0.08857174458179051
# The BundleExplorer: A Focus and Context Rendering Framework for Complex Fiber Distributions : 0.08870043651401094
# DockVis: Visual Analysis of Molecular Docking Data : 0.08870400953576807
# Medical Animations: A Survey and a Research Agenda : 0.08882128892039942
# Concentric Circle Glyphs for Enhanced Depth-Judgment in Vascular Models : 0.08883448911611158
# Semantic Screen-Space Occlusion for Multiscale Molecular Visualization : 0.08942022408936334
# Illustrative PET/CT Visualisation of SIRT-Treated Lung Metastases : 0.08950417718871317
# Monte-Carlo Ray-Tracing for Realistic Interactive Ultrasound Simulation : 0.08976831924350814
# Evaluation of Transfer Function Methods in Direct Volume Rendering of the Blood Vessel Lumen : 0.0899436364937698
# Visual Assessment of Growth Prediction in Brain Structures after Pediatric Radiotherapy : 0.09008118515980779
# Visual Analysis of Integrated Resting State Functional Brain Connectivity and Anatomy : 0.09020147110031862
# How to Evaluate Medical Visualizations on the Example of 3D Aneurysm Surfaces : 0.09063374805216773
# Interactive Visualization of Muscle Activity During Limb Movements: Towards Enhanced Anatomy Learning : 0.09066527272656033
# Feasibility Study For Automatic Bird Tracking and Visualization from Time-Dependent Marine Radar Imagery : 0.09073153581025184
# Parameterization and Feature Extraction for the Visualization of Tree-like Structures : 0.09078447244282217
# Reconstruction of Blood Vessels from Neck CT Datasets using Stable 3D Mass-Spring Models : 0.09122953708414194
# Automatic Segmentation of the Pelvic Bones from CT Data Based on a Statistical Shape Model : 0.09141199641383313
# A Web-based Application for the Visual Exploration of Colon Morphology Data : 0.09157136385959341
# Volume Visualization Using Principal Component Analysis : 0.09157210788701242
# Visual Analysis of Bipartite Biological Networks : 0.09188957018825372
# Visual Analysis of Regional Anomalies in Myocardial Motion : 0.09197444322027726
# Introducing CNN-Based Mouse Grim Scale Analysis for Fully Automated Image-Based Assessment of Distress in Laboratory Mice : 0.09215789870732538
# Interactive Visual Similarity Analysis of Measured and Simulated Multi-field Tubular Flow Ensembles : 0.09227837111356918
# Uncertainty-Guided Semi-Automated Editing of CNN-based Retinal Layer Segmentations in Optical Coherence Tomography : 0.09246191632372691
# Visual Analytics of Missing Data in Epidemiological Cohort Studies : 0.09247884044735055
# Interactive Multimodal Imaging Visualization for Multiple Sclerosis Lesion Analysis : 0.09278271980706876
# Molecular Sombreros: Abstract Visualization of Binding Sites within Proteins : 0.09296895960851759
# Histology-Based Evaluation of Optical Coherence Tomographic Characteristics of the Cerebral Artery Wall via Virtual Inflating : 0.0930042151338184
# Interactive Labeling of Toponome Data : 0.09343731690517065
# MedUse: A Visual Analysis Tool for Medication Use Data in the ABCD Study : 0.09360897420110914
# A Survey on Visualizing Magnetic Resonance Spectroscopy Data : 0.09371273892795373
# Unfolding and Interactive Exploration of Protein Tunnels and their Dynamics : 0.09389826218092479
# Visual Analysis of Evolution of EEG Coherence Networks employing Temporal Multidimensional Scaling : 0.09426714496048783
# Lowest-Variance Streamlines for Filtering of 3D Ultrasound : 0.09446390368787716
# CoWRadar: Visual Quantification of the Circle of Willis in Stroke Patients : 0.09448348970952902
# CT Late Enhancement Segmentation for the Combined Analysis of Coronary Arteries and Myocardial Viability : 0.09464616257196701
# Combining B-Mode and Color Flow Vessel Segmentation for Registration of Hepatic CT and Ultrasound Volumes : 0.09483246646980648
# Survey of Labeling Techniques in Medical Visualizations : 0.09483637229344377
# Visualizing and Exploring Dynamic Multichannel EEG Coherence Networks : 0.09495654676483523
# Computational Steering for Patient-Specific Implant Planning in Orthopedics : 0.0956495823133432
# Coherence Maps for Blood Flow Exploration : 0.09592135598854801
# Using Position-Based Dynamics for Simulating the Mitral Valve in a Decision Support System : 0.09608041283095436
# Visualizing White Matter Fiber Tracts with Optimally Fitted Curved Dissection Surfaces : 0.09627894030531725
# Illustrative Transitions in Molecular Visualization via Forward and Inverse Abstraction Transform : 0.0963756367778631
# Staircase-Aware Smoothing of Medical Surface Meshes : 0.09661934098231484
# Shading Style Assessment for Vessel Wall and Lumen Visualization : 0.09668432559287221
# Analyzing Protein Similarity by Clustering Molecular Surface Maps : 0.09686121902889255
# A Haptic Rendering Algorithm for Molecular Interaction : 0.09689232892626931
# Surface Curvature Line Clustering for Polyp Detection in CT Colonography : 0.09714049495893562
# Semantic Segmentation of Brain Tumors in MRI Data Without any Labels : 0.09724139691537204
# Visibility-Driven Processing of Streaming Volume Data : 0.09743414176925569
# Interactive Classification of Multi-Shell Diffusion MRI With Features From a Dual-Branch CNN Autoencoder : 0.09759179959465314
# Distance Field Visualization and 2D Abstraction of Vessel Tree Structures with on-the-fly Parameterization : 0.09779869161799548
# A Feasibility Study on Automated Protein Aggregate Characterization Utilizing a Hybrid Classification Model : 0.09791464416784823
# Interactive Real Time Simulation of Cardiac Radio-Frequency Ablation : 0.09799859438482694
# AR-Assisted Craniotomy Planning for Tumour Resection : 0.09819689402885767
# Visual Analysis of Medical Image Segmentation Feature Space for Interactive Supervised Classification : 0.09834596735507273
# Improving Perception of Molecular Surface Visualizations by Incorporating Translucency Effects : 0.09859594924666049
# Geometrical-Acoustics-based Ultrasound Image Simulation : 0.0987274490681116
# A Survey of Cardiac 4D PC-MRI Data Processing : 0.09930030727793793
# Learning Hand Anatomy with Sense of Embodiment : 0.09951494695471685
# Automatic Animations to Analyze Blood Flow Data : 0.09962490445985983
# Information-based Transfer Functions for Multimodal Visualization : 0.09974419255181566
# FoldSynth: Interactive 2D/3D Visualisation Platform for Molecular Strands : 0.09987979011543102
# Interactive Position-dependent Customization of Transfer Function Classification Parameters in Volume Rendering : 0.09995132524634565
# A General Approach to Model Biomedical Data from 3D Unorganised Point Clouds with Medial Scaffolds : 0.10014685755404706
# Exploration of Interventricular Septum Motion in Multi-Cycle Cardiac MRI : 0.1004275084313937
# High-Quality Multimodal Volume Visualization of Intracerebral Pathological Tissue : 0.10044899514451555
# Evaluation of Hippocampal Segmentation Methods for Healthy and Pathological Subjects : 0.10054446110407356
# Bone Fracture and Lesion Assessment using Shape-Adaptive Unfolding : 0.10132152874247746
# Automatic Hepatocyte Quantification from Histological Images: Comparing Pre-smoothing filters : 0.10139461775973235
# Robust Classification and Analysis of Anatomical Surfaces Using 3D Skeletons : 0.10158896523274508
# Visual Exploratory Analysis for Multiple T-Maze Studies : 0.10166999214562755
# HIFUtk: Visual Analytics for High Intensity Focused Ultrasound Simulation : 0.10182000851000017
# UI-Net: Interactive Artificial Neural Networks for Iterative Image Segmentation Based on a User Model : 0.10192362595349802
# Multi-fiber Estimation and Tractography for Diffusion MRI using mixture of Non-central Wishart Distributions : 0.10214635439966036
# A Guided Spatial Transformer Network for Histology Cell Differentiation : 0.10215401442775873
# Impact of Physical Noise Modeling on Image Segmentation in Echocardiography : 0.10302738561346203
# VirtualDSA++: Automated Segmentation, Vessel Labeling, Occlusion Detection and Graph Search on CT-Angiography Data : 0.10336274124497591
# Robustness Evaluation of CFD Simulations to Mesh Deformation : 0.10374953327662029
# Personalized X-ray Reconstruction of the Proximal Femur via a New Control Point-based 2D-3D Registration and Residual Complexity Minimization : 0.10375647812475086
# Misalignment Correction in Open Cone-Beam CT : 0.10379753585674945
# Guided Visualization of Ultrasound Image Sequences : 0.10382045598354328
# Parametric-based Reconstruction Of 3D Mesh Models; Towards the Generation of a Parametric Human Foot Biomodel : 0.10454923022792595
# Visual Analysis and Comparison of Multiple Sequence Alignments : 0.1049862446897859
# Ultrasound Decompression for Large Field-of-View Reconstructions : 0.1051255776751654
# Accelerated Diffusion Operators for Enhancing DW-MRI : 0.10561218147588336
# Fast and Smooth Interactive Segmentation of Medical Images Using Variational Interpolation : 0.10570342855894432
# 2.5D Geometric Mapping of Aortic Blood Flow Data for Cohort Visualization : 0.10667590885098188
# Importance-Driven Structure Categorization for 3D Surgery Planning : 0.10693639106569364
# Feature Exploration using Local Frequency Distributions in Computed Tomography Data : 0.10704817941801781
# Automated Slice-Based Artery Identification in Various Field-of-View CTA Scans : 0.10738617165330189
# A Web-Based Tool for Cardiac Dyssynchrony Assessment on Ultrasound Data : 0.10759886954041054
# A Multilinear Model for Bidirectional Craniofacial Reconstruction : 0.1078171343310308
# Global and Local Mesh Morphing for Complex Biological Objects from µCT Data : 0.10811159399873338
# Automatic Cutting and Flattening of Carotid Artery Geometries : 0.1088306265324891
# Fully Automatic Skull-Stripping in 3D Time-of-Flight MRA Image Sequences : 0.108852898058031
# GPU Accelerated Normalized Mutual Information and B-Spline Transformation : 0.11053704380206586
# Reducing Model Uncertainty in Crossing Fiber Tractography : 0.1117631501808356
# Generation of a Mean Motion Model of the Lung Using 4D-CT Image Data : 0.11203698476515489
# A Framework for Fast Initial Exploration of PC-MRI Cardiac Flow : 0.11252026853832542
# Inlier Detection in Thermal Sensitive Images : 0.11277064050243024
# On the Value of Multi-Volume Visualization for Preoperative Planning of Cerebral AVM Surgery : 0.1131458670000276
# Anatomical Volume Visualization with Weighted Distance Fields : 0.1134808679297753
# Focus + Context Rendering of Structured Biomedical Data : 0.11349779559346429
# Visual Assessment of Vascular Torsion using Ellipse Fitting : 0.11356749977295233
# Graph Averaging as a Means to Compare Multichannel EEG Coherence Networks : 0.1137972945459983
# cellVIEW: a Tool for Illustrative and Multi-Scale Rendering of Large Biomolecular Datasets : 0.11388621106646446
# A Framework for Visual Comparison of 4D PC-MRI Aortic Blood Flow Data : 0.11390722047651836
# Estimation of Muscle Activity in One-Leg Stance from 3D Surface Deformation : 0.1143692409572562
# Illustrated Ultrasound for Multimodal Data Interpretation of Liver Examinations : 0.11438603929496904
# Visualizing Movements of Protein Tunnels in Molecular Dynamics Simulations : 0.11441852306933953
# Multiparametric Magnetic Resonance Image Synthesis using Generative Adversarial Networks : 0.11467748277098422
# Constrained Labeling of 2D Slice Data for Reading Images in Radiology : 0.11501247607082288
# Polar Space Based Shape Averaging for Star-shaped Biological Objects : 0.11576810414662841
# Visually Guided Mesh Smoothing for Medical Applications : 0.11618570745369328
# A Haptics-enabled Simulator for Transperineal Ultrasound-Guided Biopsy : 0.11685813803993672
# Automatic Thrombus Detection in Non-enhanced Computed Tomography Images in Patients With Acute Ischemic Stroke : 0.11691899894389668
# Deriving Anatomical Context from 4D Ultrasound : 0.11732303779152786
# Motion-moderated Transfer Function for Volume Rendering 4D CMR Data : 0.11736713764488227
# Uncertainty-aware Ensemble of Classifiers for Segmenting Brain MRI Data : 0.118030880662231
# Temporal Interpolation of 4D PC-MRI Blood-flow Measurements Using Bidirectional Physics-based Fluid Simulation : 0.11837619171531832
# Semi-Automatic Vessel Boundary Detection in Cardiac 4D PC-MRI Data Using FTLE fields : 0.1194200730045698
# Annotated Dendrograms for Neurons From the Larval Fruit Fly Brain : 0.11944984578688866
# Progressive and Efficient Multi-Resolution Representations for Brain Tractograms : 0.11946173682021766
# Haptics-based Modelling of Pigmented Skin Lesions : 0.11997428376358488
# A Comparative User Study of a 2D and an Autostereoscopic 3D Display for a Tympanoplastic Surgery : 0.12072058223600912
# MRI Hip Joint Segmentation: A Locally Bhattacharyya Weighted Hybrid 3D Level Set Approach : 0.12265629773811959
# Strategies for Generating Multi-Time Frame Localization of Cardiac MRI : 0.123122935097981
# Dynamic Visualisation of Orbital Fat Deformation using Anatomy-Guided Interaction : 0.12445091243212403
# Maximizing AUC with Deep Learning for Classification of Imbalanced Mammogram Datasets : 0.12558516080079551
# Imaging the Vascular Network of the Human Spleen from Immunostained Serial Sections : 0.12573971219759683
# Challenges and Technologies for Low Cost Wheelchair Simulation : 0.12764614848046485
# A New Vessel Enhancement Transform on Retinal Blood Vessels Segmentation : 0.12881972770140082
# Colonic Content Assessment from MRI Imaging Using a Semi-automatic Approach : 0.1293450832729952
# An Endoscope Interface for Immersive Virtual Reality : 0.13139702694919242
# Real-Time Guidance and Anatomical Information by Image Projection onto Patients : 0.13372361183500436
# A Two-Level Cascade Classification Algorithm for Real-Time Bifurcation Detection in CTA Images of Blood Vessels : 0.1345434271429562
# Efficient Globally Optimal Matching of Anatomical Trees of the Liver : 0.13470320569680772
# A Statistical Method for Surface Detection : 0.13723733129032845
# Instant Visualization of Secondary Structures of Molecular Models : 0.1474251346370572
# Ontology-Based Visualization of Hierarchical Neuroanatomical Structures : 0.1526668322385576
# Computation of More Channels in Protein Molecules : 0.15377669760552837
# Image Registration Methods for Patient-Specific Virtual Physiological Human Models : 0.15405443428438503
# Visualisation of PET data in the Fly Algorithm : 0.1558093618624613
# Estimation of the Midsagittal Plane for Sideness Determination of Malignant Structures of Head and Neck : 0.168470039031966
# Recent Advances in MRI and Ultrasound Perfusion Imaging : 0.19000283786647743
# SWiFT Seeing the Wood From the Trees: helping people make sense of their health data : 0.19790498787355837
# Simulated Motion Artefact in Computed Tomography : 0.20653130103569894
# Automatic Real-time Annotation of Important Landmarks in Ultrasound-Guided Femoral Nerve Blocks : 0.22810150513811722
# Visual Analytics in Digital Pathology: Challenges and Opportunities : 0
# Visual Analytics in Histopathology Diagnostics: a Protocol-Based Approach : 0.04152323098437194
# PATHONE: From one Thousand Patients to one Cell : 0.09843051130024771
# Discovering Medical Knowledge Using Visual Analytics : 0.1350872502478403
# Visual Analytics in Digital Pathology: Challenges and Opportunities : 0
# Visual Analytics in Histopathology Diagnostics: a Protocol-Based Approach : 0.043578611853863025
# GLANCE: Visual Analytics for Monitoring Glaucoma Progression : 0.05849451299711139
# Discovering Medical Knowledge Using Visual Analytics : 0.06178798678688868
# array([[ 1,  1],
#        [ 2, 51],
#        [ 3,  3],
#        [34,  2]])

# %%
def calculate_dist(model, paper, target):
    f = open(f'../embeddings/high_dimension/{model}_high_dim.json')
    data = json.load(f)
    target_emb = data[target]
    paper_emb = data[paper]
    dist = distance.cosine(target_emb, paper_emb)
    return dist

# %%
model = "pubmedbert"
target = "Visual Analytics in Digital Pathology: Challenges and Opportunities"
paper1 = "Visual Analytics in Histopathology Diagnostics: a Protocol-Based Approach"
dist = calculate_dist(model, paper1, target)
dist
# Out:
# 0.043578611853863025

# %%
with open('../articles_data/all_articles_with_thumbnail_metadata.json') as f:
    papers = json.load(f)

article_titles = [paper['article_title'] for paper in papers]

# %%
with open('../articles_data/all_articles_with_thumbnail_metadata.json') as f:
    papers = json.load(f)

article_titles = [paper['article_title'] for paper in papers]

# %%
def create_rank_matrix(target_title, K, drawplot=False):
    # models = ['allenai_specter','all_mpnet_base_v2','biowordvec',
    #           'generic_fasttext', 'TFIDF', 'BOW']
    # model_names = ['allenai_specter','all_mpnet_base_v2','BioWordVec',
    #           'Generic fastText','TFIDF','BOW']

    # model_names = ['BioWordVec','Generic fastText']
    models = ['allenai_specter', 'pubmedbert', 'generic_fasttext']
    model_names = ['allenai_specter', 'PubMedBERT', 'Avg. Generic fastText']

    all_points = {model: load_points(model, target_title, k=236) for model in models}
    points = {model: load_points(model, target_title, k=K) for model in models}

    # print(len(points))
    allkey = reduce(set.union, map(set, map(dict.keys, points.values())))
    if target_title in allkey:
        allkey.remove(target_title)

    d = np.zeros((len(allkey), len(models)))
    all_dist = []
    index_a = []
    for key in allkey:
        item = [points[m][key] if key in points[m] else all_points[m][key] for m in models]
        a = [list(points[m].keys()).index(key) if key in points[m] else list(all_points[m].keys()).index(key) for m in
             models]
        index_a.append(a)
        all_dist.append(item)

    A = np.array(all_dist)
    B = np.array(index_a)

    avg = np.average(A, axis=0)

    labels = ['\n'.join(wrap(l, 30)) for l in allkey]
    # my_colors = ['#08c45b', '#eded72','#926dd1','#6f6dd1', '#bf62b7']
    my_colors = ['#08c45b']
    my_cmap = ListedColormap(my_colors)
    my_cmap.set_over('#eb4f34')
    if drawplot:
        print(allkey)
        fig, ax = plt.subplots(figsize=(6, 8))
        ax = sns.heatmap(B, xticklabels=model_names, yticklabels=labels, annot=A,
                         cbar_kws={'label': 'Publication Ranks',
                                   'extend': 'max',
                                   'ticks': [0, 3]},
                         cmap=my_cmap, vmin=0, vmax=3, cbar=True, ax=ax,
                         annot_kws={'fontsize': 12, 'color': 'black', 'alpha': 1}, linewidths=0.08,
                         linecolor='lightgray')
        colorbar = ax.collections[0].colorbar
        colorbar.set_ticks([0, 3])
        colorbar.set_ticklabels(['1', '3'])
        plt.title(label=f'Distance from \"{target_title}\"', fontsize=10, fontstyle='oblique')
        plt.show()
    return B

# %%
target_title1 = "Visual Analytics in Digital Pathology: Challenges and Opportunities"
B = create_rank_matrix(target_title1, 4, True)
B
# Out:
# 127
# 70
# 61
# 74
# 207
# 133
# 184
# 84
# 49
# 25
# 146
# 37
# 112
# 229
# 26
# 227
# 56
# 48
# 89
# 98
# 123
# 151
# 225
# 149
# 199
# 198
# 216
# 4
# 30
# 143
# 185
# 141
# 136
# 230
# 161
# 180
# 138
# 196
# 221
# 44
# 144
# 82
# 142
# 152
# 3
# 131
# 129
# 50
# 104
# 201
# 79
# 47
# 117
# 228
# 150
# 224
# 75
# 55
# 175
# 92
# 66
# 81
# 58
# 110
# 235
# 93
# 187
# 128
# 69
# 124
# 78
# 177
# 57
# 173
# 171
# 29
# 164
# 162
# 96
# 114
# 68
# 145
# 200
# 101
# 233
# 43
# 73
# 76
# 159
# 41
# 223
# 208
# 97
# 64
# 121
# 13
# 231
# 63
# 178
# 86
# 42
# 77
# 9
# 219
# 52
# 234
# 40
# 174
# 105
# 222
# 8
# 109
# 166
# 71
# 1
# 34
# 72
# 220
# 85
# 2
# 45
# 137
# 113
# 147
# 203
# 100
# 38
# 53
# 62
# 31
# 156
# 214
# 211
# 210
# 0
# 87
# 226
# 99
# 125
# 139
# 33
# 28
# 22
# 60
# 148
# 46
# 135
# 67
# 126
# 182
# 209
# 15
# 168
# 94
# 65
# 90
# 153
# 59
# 165
# 122
# 170
# 119
# 27
# 191
# 157
# 106
# 192
# 176
# 218
# 169
# 11
# 107
# 54
# 120
# 186
# 188
# 91
# 12
# 7
# 17
# 194
# 116
# 80
# 88
# 215
# 167
# 83
# 111
# 51
# 6
# 108
# 16
# 35
# 205
# 213
# 163
# 32
# 179
# 172
# 10
# 190
# 20
# 202
# 118
# 217
# 232
# 206
# 102
# 154
# 24
# 39
# 197
# 19
# 160
# 18
# 21
# 134
# 23
# 181
# 195
# 115
# 212
# 132
# 14
# 5
# 155
# 193
# 189
# 158
# 95
# 103
# 140
# 36
# 130
# 183
# 204
# 127
# 70
# 161
# 74
# 38
# 12
# 3
# 87
# 26
# 109
# 104
# 219
# 156
# 50
# 75
# 144
# 94
# 196
# 152
# 118
# 123
# 202
# 232
# 93
# 151
# 143
# 43
# 159
# 235
# 171
# 210
# 175
# 30
# 66
# 25
# 107
# 18
# 207
# 124
# 42
# 19
# 225
# 174
# 77
# 126
# 189
# 97
# 41
# 129
# 184
# 231
# 61
# 76
# 72
# 133
# 1
# 8
# 99
# 149
# 23
# 146
# 169
# 16
# 78
# 106
# 142
# 137
# 24
# 5
# 29
# 186
# 227
# 119
# 63
# 101
# 31
# 157
# 131
# 83
# 138
# 0
# 173
# 49
# 110
# 176
# 141
# 179
# 53
# 117
# 69
# 199
# 233
# 213
# 32
# 234
# 170
# 217
# 136
# 215
# 21
# 198
# 27
# 9
# 112
# 230
# 145
# 28
# 2
# 86
# 214
# 128
# 113
# 164
# 59
# 229
# 209
# 185
# 114
# 181
# 120
# 7
# 188
# 71
# 84
# 103
# 172
# 226
# 36
# 163
# 147
# 203
# 162
# 90
# 95
# 201
# 14
# 44
# 35
# 13
# 220
# 183
# 206
# 98
# 228
# 20
# 105
# 167
# 45
# 4
# 208
# 224
# 92
# 192
# 205
# 116
# 33
# 79
# 60
# 6
# 47
# 218
# 140
# 81
# 165
# 80
# 160
# 166
# 11
# 56
# 212
# 57
# 168
# 195
# 73
# 52
# 221
# 216
# 222
# 85
# 17
# 194
# 125
# 130
# 150
# 155
# 65
# 139
# 153
# 67
# 48
# 177
# 64
# 115
# 34
# 68
# 39
# 180
# 190
# 10
# 82
# 46
# 55
# 182
# 91
# 22
# 111
# 154
# 158
# 148
# 193
# 58
# 51
# 134
# 191
# 54
# 223
# 96
# 200
# 204
# 40
# 100
# 88
# 37
# 211
# 187
# 89
# 178
# 102
# 132
# 121
# 122
# 15
# 108
# 135
# 197
# 62
# 127
# 70
# 61
# 161
# 185
# 138
# 196
# 113
# 184
# 219
# 52
# 141
# 74
# 144
# 93
# 105
# 235
# 104
# 143
# 25
# 152
# 63
# 112
# 1
# 10
# 123
# 38
# 207
# 169
# 42
# 220
# 66
# 6
# 86
# 136
# 209
# 31
# 26
# 156
# 69
# 72
# 56
# 41
# 67
# 128
# 82
# 7
# 47
# 205
# 2
# 176
# 173
# 174
# 14
# 43
# 137
# 22
# 98
# 68
# 34
# 45
# 214
# 232
# 57
# 218
# 199
# 202
# 116
# 101
# 217
# 103
# 131
# 124
# 146
# 37
# 94
# 175
# 12
# 84
# 20
# 49
# 50
# 170
# 3
# 149
# 133
# 96
# 78
# 126
# 24
# 147
# 106
# 139
# 154
# 216
# 165
# 150
# 100
# 145
# 30
# 225
# 35
# 189
# 223
# 77
# 83
# 224
# 117
# 230
# 168
# 221
# 210
# 180
# 110
# 153
# 109
# 229
# 85
# 28
# 130
# 81
# 89
# 4
# 120
# 29
# 75
# 213
# 233
# 234
# 0
# 151
# 157
# 171
# 65
# 158
# 114
# 215
# 8
# 206
# 192
# 54
# 97
# 228
# 44
# 188
# 92
# 231
# 59
# 179
# 11
# 119
# 181
# 195
# 177
# 111
# 203
# 76
# 186
# 46
# 129
# 148
# 166
# 200
# 159
# 23
# 178
# 9
# 58
# 226
# 172
# 142
# 48
# 40
# 16
# 162
# 21
# 198
# 134
# 64
# 227
# 71
# 182
# 194
# 95
# 79
# 53
# 222
# 5
# 33
# 17
# 122
# 125
# 167
# 132
# 155
# 118
# 13
# 115
# 212
# 90
# 208
# 102
# 204
# 19
# 164
# 190
# 191
# 55
# 135
# 107
# 183
# 36
# 87
# 163
# 80
# 51
# 160
# 121
# 140
# 187
# 73
# 18
# 201
# 88
# 39
# 27
# 99
# 211
# 15
# 32
# 60
# 108
# 193
# 91
# 197
# 62
# 127
# 70
# 61
# 74
# 127
# 70
# 161
# 74
# 127
# 70
# 61
# 161
# {'Discovering Medical Knowledge Using Visual Analytics', 'PATHONE: From one Thousand Patients to one Cell', 'GLANCE: Visual Analytics for Monitoring Glaucoma Progression', 'Visual Analytics in Histopathology Diagnostics: a Protocol-Based Approach'}
# array([[ 3,  3, 12],
#        [ 2, 51,  2],
#        [34,  2,  3],
#        [ 1,  1,  1]])

# %%
# import pandas as pd

# target_title1 = "A Framework for Visual Comparison of 4D PC-MRI Aortic Blood Flow Data"
# target_title2 = "Visual Analytics in Digital Pathology: Challenges and Opportunities"
# article = "A Framework for Visual Comparison of 4D PC-MRI Aortic Blood Flow Data"
# A, B = draw_plot(article)

# draw_plot(target_title2)
# models = ['all-mpnet-base-v2', 'allenai-specter', 'BioBERT', 'PubMedBert', 'BioWordVec',
#           'Generic fastText']
# rank_matrix = []
# dist_matrix = []
# count = 0
# all_cor_mat = []
# all_dist_mat = []
# # draw_plot(target_title3)
# for article in article_titles:
#     B = create_rank_matrix(article, K=5)
#     # x = A.mean(axis=0)
#     # all_dist_mat.append(x)
#     df = pd.DataFrame(B)
#     cor_B = df.corr(method="spearman")
#     all_cor_mat.append(cor_B)


#     dist_matrix.append(A)
#     rank_matrix.append(B)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [313], in <cell line: 17>()
#      16 # draw_plot(target_title3)
#      17 for article in article_titles:
# ---> 18     B = create_rank_matrix(article, K=5)
#      19     # x = A.mean(axis=0)
#      20     # all_dist_mat.append(x)
#      21     df = pd.DataFrame(B)
#
# Input In [311], in create_rank_matrix(target_title, K, drawplot)
#       9 model_names = ['allenai_specter', 'PubMedBERT', 'Avg. Generic fastText']
#      11 all_points = {model: load_points(model, target_title, k=236) for model in models}
# ---> 12 points = {model: load_points(model, target_title, k=K) for model in models}
#      14 # print(len(points))
#      15 allkey = reduce(set.union, map(set, map(dict.keys, points.values())))
#
# Input In [311], in <dictcomp>(.0)
#       9 model_names = ['allenai_specter', 'PubMedBERT', 'Avg. Generic fastText']
#      11 all_points = {model: load_points(model, target_title, k=236) for model in models}
# ---> 12 points = {model: load_points(model, target_title, k=K) for model in models}
#      14 # print(len(points))
#      15 allkey = reduce(set.union, map(set, map(dict.keys, points.values())))
#
# Input In [307], in load_points(model, article, k)
#       1 def load_points(model, article, k):
#       2     f = open(f'../embeddings/high_dimension/{model}_high_dim.json')
# ----> 3     data = json.load(f)
#       4     target = data[article]
#       5     articles_title = list(data.keys())
#
# File ~/opt/miniconda3/envs/newpy/lib/python3.8/json/__init__.py:293, in load(fp, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     274 def load(fp, *, cls=None, object_hook=None, parse_float=None,
#     275         parse_int=None, parse_constant=None, object_pairs_hook=None, **kw):
#     276     """Deserialize ``fp`` (a ``.read()``-supporting file-like object containing
#     277     a JSON document) to a Python object.
#     278
#    (...)
#     291     kwarg; otherwise ``JSONDecoder`` is used.
#     292     """
# --> 293     return loads(fp.read(),
#     294         cls=cls, object_hook=object_hook,
#     295         parse_float=parse_float, parse_int=parse_int,
#     296         parse_constant=parse_constant, object_pairs_hook=object_pairs_hook, **kw)
#
# File ~/opt/miniconda3/envs/newpy/lib/python3.8/json/__init__.py:357, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     352     del kw['encoding']
#     354 if (cls is None and object_hook is None and
#     355         parse_int is None and parse_float is None and
#     356         parse_constant is None and object_pairs_hook is None and not kw):
# --> 357     return _default_decoder.decode(s)
#     358 if cls is None:
#     359     cls = JSONDecoder
#
# File ~/opt/miniconda3/envs/newpy/lib/python3.8/json/decoder.py:337, in JSONDecoder.decode(self, s, _w)
#     332 def decode(self, s, _w=WHITESPACE.match):
#     333     """Return the Python representation of ``s`` (a ``str`` instance
#     334     containing a JSON document).
#     335
#     336     """
# --> 337     obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338     end = _w(s, end).end()
#     339     if end != len(s):
#
# File ~/opt/miniconda3/envs/newpy/lib/python3.8/json/decoder.py:353, in JSONDecoder.raw_decode(self, s, idx)
#     344 """Decode a JSON document from ``s`` (a ``str`` beginning with
#     345 a JSON document) and return a 2-tuple of the Python
#     346 representation and the index in ``s`` where the document ended.
#    (...)
#     350
#     351 """
#     352 try:
# --> 353     obj, end = self.scan_once(s, idx)
#     354 except StopIteration as err:
#     355     raise JSONDecodeError("Expecting value", s, err.value) from None
#
# KeyboardInterrupt:

# %%
# x = np.array(all_dist_mat).mean(axis=0)
# x

# %%
# all_cor_mat = np.array(all_cor_mat)
# x = np.mean(all_cor_mat, axis=0)
# y = pd.DataFrame(x, columns=['all-mpnet-base-v2', 'allenai-specter', 'BioBERT', 'PubMedBert', 'BioWordVec',
#                              'Generic fastText'])
# sns.heatmap(y, cmap="coolwarm", mask=np.triu(y), yticklabels=models, annot=y)

# %%
# import pandas as pd
#
# df = pd.DataFrame(B, columns=['all_mpnet', 'allenai', 'biowordvec', 'generic_fast'])
# my_r = df.corr(method="spearman")
# fig, ax = plt.subplots(figsize=(6, 6))
# sns.heatmap(my_r, cmap="coolwarm", mask=np.triu(my_r))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [54], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.DataFrame(B, columns=['all_mpnet', 'allenai','biowordvec','generic_fast'])
#       3 my_r = df.corr(method="spearman")
#       4 fig, ax = plt.subplots(figsize=(6, 6))
#
# File ~/opt/miniconda3/envs/newpy/lib/python3.8/site-packages/pandas/core/frame.py:694, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     684         mgr = dict_to_mgr(
#     685             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     686             # attribute "name"
#    (...)
#     691             typ=manager,
#     692         )
#     693     else:
# --> 694         mgr = ndarray_to_mgr(
#     695             data,
#     696             index,
#     697             columns,
#     698             dtype=dtype,
#     699             copy=copy,
#     700             typ=manager,
#     701         )
#     703 # For data is list-like, or Iterable (will consume into list)
#     704 elif is_list_like(data):
#
# File ~/opt/miniconda3/envs/newpy/lib/python3.8/site-packages/pandas/core/internals/construction.py:351, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     346 # _prep_ndarray ensures that values.ndim == 2 at this point
#     347 index, columns = _get_axes(
#     348     values.shape[0], values.shape[1], index=index, columns=columns
#     349 )
# --> 351 _check_values_indices_shape_match(values, index, columns)
#     353 if typ == "array":
#     355     if issubclass(values.dtype.type, str):
#
# File ~/opt/miniconda3/envs/newpy/lib/python3.8/site-packages/pandas/core/internals/construction.py:422, in _check_values_indices_shape_match(values, index, columns)
#     420 passed = values.shape
#     421 implied = (len(index), len(columns))
# --> 422 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (14, 6), indices imply (14, 4)

# %%
# import pandas as pd
#
# df = pd.DataFrame(B, columns=['all_mpnet', 'allenai', 'biobert', 'pubmedbert', 'biowordvec', 'generic_fast', 'tfidf',
#                               'bow'])
# my_r = df.corr(method="spearman")
# fig, ax = plt.subplots(figsize=(6, 6))
# sns.heatmap(my_r, cmap="coolwarm", mask=np.triu(my_r))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [55], in <cell line: 2>()
#       1 import pandas as pd
# ----> 2 df = pd.DataFrame(B, columns=['all_mpnet', 'allenai','biobert','pubmedbert','biowordvec','generic_fast','tfidf','bow'])
#       3 my_r = df.corr(method="spearman")
#       4 fig, ax = plt.subplots(figsize=(6, 6))
#
# File ~/opt/miniconda3/envs/newpy/lib/python3.8/site-packages/pandas/core/frame.py:694, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     684         mgr = dict_to_mgr(
#     685             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     686             # attribute "name"
#    (...)
#     691             typ=manager,
#     692         )
#     693     else:
# --> 694         mgr = ndarray_to_mgr(
#     695             data,
#     696             index,
#     697             columns,
#     698             dtype=dtype,
#     699             copy=copy,
#     700             typ=manager,
#     701         )
#     703 # For data is list-like, or Iterable (will consume into list)
#     704 elif is_list_like(data):
#
# File ~/opt/miniconda3/envs/newpy/lib/python3.8/site-packages/pandas/core/internals/construction.py:351, in ndarray_to_mgr(values, index, columns, dtype, copy, typ)
#     346 # _prep_ndarray ensures that values.ndim == 2 at this point
#     347 index, columns = _get_axes(
#     348     values.shape[0], values.shape[1], index=index, columns=columns
#     349 )
# --> 351 _check_values_indices_shape_match(values, index, columns)
#     353 if typ == "array":
#     355     if issubclass(values.dtype.type, str):
#
# File ~/opt/miniconda3/envs/newpy/lib/python3.8/site-packages/pandas/core/internals/construction.py:422, in _check_values_indices_shape_match(values, index, columns)
#     420 passed = values.shape
#     421 implied = (len(index), len(columns))
# --> 422 raise ValueError(f"Shape of passed values is {passed}, indices imply {implied}")
#
# ValueError: Shape of passed values is (14, 6), indices imply (14, 8)

# %%
# a = np.array(8)
# A = np.append(a, B)
# A

# %%
# import pandas as pd
#
# df = pd.DataFrame(B, columns=['all_mpnet', 'allenai', 'biobert', 'pubmedbert', 'biowordvec', 'generic_fast'])
# my_r = df.corr(method="spearman")
# fig, ax = plt.subplots(figsize=(6, 6))
# sns.heatmap(my_r, cmap="coolwarm", mask=np.triu(my_r))

# %%
def generate_rank_matrix(target_title, K, drawplot=False):
    models = ['allenai_specter', 'all_mpnet_base_v2', 'pubmedbert', 'biowordvec',
              'generic_fasttext', 'tfidf', 'bow']
    model_names = ['all-mpnet-base-v2', 'allenai-specter', 'PubMedBert', 'Avg. BioWordVec',
                   'Avg. Generic fastText', 'TFIDF', 'BOW']
    # models = ['biowordvec','generic_fasttext']
    # model_names = ['BioWordVec','Generic fastText']
    # models = ['allenai_specter','all_mpnet_base_v2']
    # model_names = ['allenai_specter','all_mpnet_base_v2']

    all_points = {model: load_points(model, target_title, k=236) for model in models}
    points = {model: load_points(model, target_title, k=K) for model in models}

    articles_from_models = [r for x in list(points.values()) for r in x]

    # print(len(points))
    allkey = reduce(set.union, map(set, map(dict.keys, points.values())))
    if target_title in articles_from_models:
        articles_from_models.remove(target_title)

    d = np.zeros((len(allkey), len(models)))
    all_dist = []
    index_a = []
    for key in articles_from_models:
        item = [points[m][key] if key in points[m] else all_points[m][key] for m in models]
        a = [list(points[m].keys()).index(key) if key in points[m] else list(all_points[m].keys()).index(key) for m in
             models]
        index_a.append(a)
        all_dist.append(item)

    A = np.array(all_dist)
    B = np.array(index_a)

    avg = np.average(A, axis=0)

    labels = ['\n'.join(wrap(l, 50)) for l in articles_from_models]
    my_colors = ['#08c45b']
    my_cmap = ListedColormap(my_colors)
    my_cmap.set_over('#eb4f34')
    if drawplot:
        fig, ax = plt.subplots(figsize=(6, 6))
        ax = sns.heatmap(B, xticklabels=model_names, yticklabels=labels, annot=A,
                         cbar_kws={'label': 'Publication Ranks',
                                   'extend': 'max',
                                   'ticks': [1, 2]},
                         cmap=my_cmap, vmin=1, vmax=2, cbar=True, ax=ax,
                         annot_kws={'fontsize': 12, 'color': 'black', 'alpha': 1}, linewidths=0.08,
                         linecolor='lightgray')
        colorbar = ax.collections[0].colorbar
        colorbar.set_ticks([1, 2])
        colorbar.set_ticklabels(['1', '2'])
        plt.title(label=f'Distance from \"{target_title}\"', fontsize=10, fontstyle='oblique')
        plt.show()
    return B

# %%
import pandas as pd

# target_title1 = "A Framework for Visual Comparison of 4D PC-MRI Aortic Blood Flow Data"
# target_title2 = "Visual Analytics in Digital Pathology: Challenges and Opportunities"
# article = "A Framework for Visual Comparison of 4D PC-MRI Aortic Blood Flow Data"
# A, B = draw_plot(article)

# draw_plot(target_title2)
models = ['all-mpnet-base-v2', 'allenai-specter', 'PubMedBert', 'Avg. BioWordVec',
          'Avg. Generic fastText', 'TFIDF', 'BOW']
model_names = ['all-mpnet-base-v2', 'allenai-specter', 'PubMedBert', 'Avg. BioWordVec',
               'Avg. Generic fastText', 'TFIDF', 'BOW']
rank_matrix = []
dist_matrix = []
count = 0
all_mat = []
all_dist_mat = []
# draw_plot(target_title3)
for article in article_titles:
    B = generate_rank_matrix(article, K=6, drawplot=False)
    df = pd.DataFrame(B)
    all_mat.append(df)

# %%
R = np.mean(np.array(all_mat), axis=0)
R
# Out:
# array([[ 0.        ,  6.57627119, 50.11016949, 21.18644068, 21.44915254,
#         20.77118644, 27.6440678 ],
#        [ 1.        ,  9.84745763, 57.63983051, 25.63559322, 27.14830508,
#         30.79237288, 36.19915254],
#        [ 2.        , 10.61864407, 62.84745763, 35.26271186, 34.51694915,
#         35.43644068, 39.01694915],
#        [ 3.        , 17.05508475, 73.52542373, 39.27966102, 37.26694915,
#         39.78389831, 46.27542373],
#        [ 4.        , 15.51271186, 67.19067797, 38.23305085, 40.28389831,
#         37.52118644, 44.6059322 ],
#        [ 6.22457627,  0.        , 50.45762712, 17.97881356, 19.34745763,
#         16.88559322, 22.66949153],
#        [ 9.37288136,  1.        , 57.70338983, 24.02542373, 26.12288136,
#         25.44915254, 29.51271186],
#        [13.18644068,  2.        , 60.97881356, 25.91949153, 25.86016949,
#         23.63983051, 28.1440678 ],
#        [14.8940678 ,  3.        , 60.98728814, 32.66949153, 32.59745763,
#         32.28813559, 37.11016949],
#        [16.99152542,  4.        , 71.70338983, 33.41525424, 34.10169492,
#         35.83050847, 41.11864407],
#        [34.55932203, 32.46186441,  0.        , 34.08898305, 36.52118644,
#         41.97033898, 44.67372881],
#        [48.53813559, 41.40254237,  1.        , 50.45338983, 55.6779661 ,
#         60.91949153, 62.02966102],
#        [53.88559322, 49.42372881,  2.        , 49.33474576, 51.70338983,
#         63.09322034, 69.22033898],
#        [60.02118644, 55.46186441,  3.        , 55.59745763, 59.46186441,
#         75.94915254, 77.77542373],
#        [61.31355932, 56.33898305,  4.        , 60.94067797, 66.54661017,
#         74.05508475, 76.14830508],
#        [15.11864407, 11.        , 46.9279661 ,  0.        ,  3.52542373,
#         16.19491525, 20.0720339 ],
#        [22.77542373, 19.07627119, 54.06355932,  1.        ,  5.72881356,
#         24.00847458, 26.98728814],
#        [29.77542373, 24.96186441, 57.27118644,  2.        ,  7.86440678,
#         34.98728814, 37.27118644],
#        [31.30932203, 24.92372881, 65.31355932,  3.        ,  9.83474576,
#         34.02542373, 35.39830508],
#        [34.11440678, 31.30084746, 59.88559322,  4.        , 11.15677966,
#         41.81779661, 43.82627119],
#        [17.00423729, 11.38135593, 54.03389831,  2.83474576,  0.        ,
#         13.20762712, 15.90254237],
#        [26.44491525, 19.80508475, 54.19491525,  5.8559322 ,  1.        ,
#         20.43220339, 22.6059322 ],
#        [29.43644068, 22.08898305, 57.72033898,  7.0720339 ,  2.        ,
#         25.48305085, 28.29661017],
#        [36.1440678 , 31.76271186, 64.33050847, 10.6779661 ,  3.        ,
#         25.88559322, 28.60169492],
#        [38.44915254, 32.76271186, 68.00847458, 12.47457627,  4.        ,
#         34.38559322, 33.51694915],
#        [26.19067797, 19.55508475, 58.83050847, 23.41949153, 21.15677966,
#          0.        ,  1.44067797],
#        [32.44067797, 26.09322034, 68.37288136, 31.61016949, 27.91101695,
#          1.        ,  4.13559322],
#        [42.24152542, 32.98728814, 68.49152542, 36.50847458, 33.38983051,
#          2.        ,  6.61864407],
#        [42.77118644, 36.99576271, 76.51694915, 36.00423729, 35.47457627,
#          3.        ,  6.63559322],
#        [47.54661017, 36.40677966, 73.30932203, 42.79237288, 41.58474576,
#          4.        ,  8.30932203],
#        [29.87288136, 23.80932203, 58.63559322, 22.59745763, 18.8940678 ,
#          1.06779661,  0.        ],
#        [38.16525424, 30.23305085, 63.1779661 , 29.30932203, 25.49576271,
#          3.34322034,  1.        ],
#        [48.41525424, 36.94067797, 73.93220339, 33.22881356, 31.69491525,
#          4.47033898,  2.        ],
#        [42.48728814, 38.16101695, 75.19067797, 38.25      , 37.42372881,
#          5.98728814,  3.        ],
#        [51.65677966, 42.34322034, 77.83474576, 41.4279661 , 38.02966102,
#          7.8940678 ,  4.        ]])

# %%
from scipy.stats import spearmanr

pvalues = []
main = []
for i in range(len(model_names)):
    for j in range(len(model_names)):
        rho, pr = spearmanr(R[:, i], R[:, j])
        pvalues.append(pr)
        if j == len(model_names) - 1:
            main.append(pvalues)
            pvalues = []
df1 = pd.DataFrame(main, columns=model_names)
fig, ax = plt.subplots(figsize=(6, 6))
sns.heatmap(df1, cmap="coolwarm", mask=np.triu(df1), annot=True, fmt='.3f', cbar_kws={'ticks': [0.05]})
# Out:
# <AxesSubplot:>

# %%
import pandas as pd

df = pd.DataFrame(R, columns=['all-mpnet-base-v2', 'allenai-specter', 'PubMedBert', 'Avg. BioWordVec',
                              'Avg. Generic fastText', 'TFIDF', 'BOW'])
my_r = df.corr(method="spearman")
fig, ax = plt.subplots(figsize=(6, 6))
sns.heatmap(my_r, cmap="coolwarm", mask=np.triu(my_r), annot=my_r, cbar_kws={'ticks': [-1, 0, 1]}, cbar=True, vmin=-1,
            vmax=1)
# Out:
# <AxesSubplot:>
